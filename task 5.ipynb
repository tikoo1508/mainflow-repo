# %%
import tkinter as tk
from tkinter import *
from tkinter import ttk
from datetime import datetime
import requests
from PIL import ImageTk, Image
from tkinter import messagebox
root = tk.Tk()
root.geometry("600x270")
root.title("currency converter")
root.iconbitmap('C:\\Users\\tikoo\\OneDrive\\Desktop\\vscode\\mainflow\\task5\\icon.ico')
root.maxsize(600,270)
root.minsize(600,270)

image = Image.open('C:\\Users\\tikoo\\OneDrive\\Desktop\\vscode\\mainflow\\task5\\currency.png')
zoom = 0.5

pixels_x, pixels_y = tuple ([int(zoom * x) for x in image.size])

img = ImageTk.PhotoImage(image.resize((pixels_x,pixels_y)))
panel = Label(root, image = img)
panel.place(x=190,y=35)

def show_data():
    amount = E1.get()
    from_currency = c1.get()
    to_currency = c2.get()
    url = 'https://api.currencylayer.com/live?access_key=4273d2c37f738367f08780b934ce7dda&format=1'

    if amount  == '':
        messagebox.showerror("currency converter", "please fill the amount")
    elif to_currency == '':
        messagebox.showerror("currency converter", "please choose currency")
    else:
        data = requests.get(url).json()
        currency = from_currency.strip()+to_currency.strip()
        amount = int(amount)
        cc = data['quotes'][currency]
        cur_conv = cc*amount
        E2.insert(0,cur_conv)
        
        text.insert('end',f'{amount} united state dollar equals {cur_conv} {to_currency}\n\n last time update -----\t {datetime.now()}')
    
def clear():
    f1.delete(0,'end')
    f2.delete(0,'end')
    text.delete(1,0,'end')

l1 = Label(root,text = "USD currency converter using python", font =('verdana','10','bold'))
l1.place(x=150, y=15)

amt = Label(root,text ="Amount",font=('roboto',10,'bold'))
amt.place(x=20,y=40)
E1 = Entry(root,width=20,borderwidth=1,font=('roboto',10,'bold'))
E1.place(x=20, y=40) 

c1 = tk.StringVar()
c2 = tk.StringVar()
currencychoose1 = ttk.Combobox(root, width=20, textvariable = c1, state='randomly', font=('verdana',10,'bold'))


currencychoose1['values'] = ('USD',
                            )

currencychoose1.place(x=300,y=40)
currencychoose1.current(0)

E2 = Entry(root,width=20,borderwidth=1,font=('roboto','10','bold'))
E2.place(x=20,y=80)

currencychoose2 = ttk.Combobox(root, width = 20,textvariable = c2, state = 'readonly', font = ('verdana','10','bold'))

currencychoose2['values']=('ALL',
                            'AFN',
                            'AWG',
                            'AUD',
                            'AZN',
                            'BSD',
                            'BBD',
                            'BZD',
                            'BMD',
                            'BOB',
                            'BAM',
                            'BWP',
                            'BGN',
                            'BND',
                            'KHR',
                            'CAD',
                            'KYD',
                            'CLP',
                            'CNY',
                            'COP',
                            'CRC',
                            'HRK',
                            'CUP',
                            'CZK',
                            'DKK',
                            'DOP',
                            'CXD',
                            'EGP',
                            'SVC',
                            'EUR',
                            'FKP',
                            'FJD',
                            'GHS',
                            'GIP',
                            'GTQ',
                            'GGP',
                            'GYD',
                            'INR',)
                            
currencychoose2.place(x=300,y=80)
currencychoose2.current()

text = Text(root,height =7,width=52,font=('verdana','10','bold'))
text.place(x=100,y=120)

B= Button(root,text="Search",command=show_data,font=('verdana','10','bold'),borderwidth=2,bg="red",fg="white")
B.place(x=20,y=120)

B= Button(root,text="Clear",command=clear,font=('verdana','10','bold'),borderwidth=2,bg="blue",fg="white")
B.place(x=20,y=170)

root.mainloop()
